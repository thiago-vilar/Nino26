# %% [markdown]
# **COMANDO WSL2 — EXECUTAR FASE COMPLETA**
#
# ```bash
# cd /mnt/c/DEV/NINO26 && .venv-wsl/bin/python scripts/run_fase6_all.py
# ```
#
# **TÍTULO**
#
# F6A — RF/XGBoost por pixel CHIRPS
#
# **Projeto:** NINO-BRASIL — Oceanografia Física — UFPE
# **Código canônico:** `F6A`
# **Objeto de estudo:** processo físico definido para esta etapa do projeto
# **Família de hipótese:** `HIP3`
#
# **CONTEXTO**
#
# Este notebook integra a Fase 6 do projeto NINO-BRASIL e responde a uma pergunta delimitada com entradas, método e saídas rastreáveis. O resultado deve ser lido como evidência da hipótese declarada, respeitando o escopo temporal, espacial e estatístico registrado no inventário de dados.
#
# **PERGUNTA CIENTÍFICA**
#
# Qual skill espacial RF/XGBoost acrescenta sobre a referência estatística?
#
# **MOTIVAÇÃO**
#
# *Hipótese específica*
#
# A hipótese HIP3 é que a pergunta — Qual skill espacial RF/XGBoost acrescenta sobre a referência estatística — pode ser avaliada com as entradas declaradas e o método abaixo; resultados nulos ou insuficientes permanecem conclusões válidas.
#
# A hipótese poderá ser sustentada, parcialmente sustentada ou rejeitada; a execução do notebook não antecipa o resultado.
#
# *Função dos testes e unidade de análise*
#
# O teste foi escolhido para manter a unidade de análise e o encadeamento temporal da fase, sem transformar observações correlacionadas em réplicas independentes. Os produtos numéricos são persistidos antes das figuras para permitir auditoria e reprodução.
#
# **METODOLOGIA**
#
# Validação temporal por evento e avaliação na grade CHIRPS nativa, sem tratar pixels-semanas como eventos independentes.
#
# **RESULTADOS ESPERADOS**
#
# Resultados esperados significam produtos necessários para responder à pergunta, não valores ou significâncias presumidos:
#
# - tabela numérica auditável que responda à pergunta científica.
# - figura correspondente, com título, unidades e escopo explícitos.
# - conclusões e limitações derivadas apenas das saídas executadas.
#
# - figuras públicas iniciadas por `FigF6A`;
# - tabelas públicas iniciadas por `TabF6A`;
# - primeiro par reservado: `FigF6A1` ↔ `TabF6A1`;
# - toda interpretação deve apontar para tabela, run_id, unidade, amostra e limitações.
#
# *Fundamentação científica mínima*
#
# As referências completas utilizadas estão na última célula do notebook.

# %% [markdown]
# **PREMISSAS DE VALIDADE E LIMITES DE INTERPRETAÇÃO**
#
# - Toda conclusão deve nascer de uma tabela `Tab...` persistida antes da figura correspondente.
# - A execução é determinística e usa somente entradas declaradas no inventário mostrado abaixo.
# - Notebook executado não implica hipótese confirmada; gates científicos são exibidos como resultados.
# - O alvo CHIRPS conserva `pixel_id`, latitude e longitude da grade nativa; não há interpolação do alvo.
# - Pré-processamento, pesos e augmentation são ajustados somente no treino de cada fold.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
NOTEBOOK_CODE = 'F6A'
MODE = os.environ.get('NINO26_NOTEBOOK_MODE', 'official')
RUN_PIPELINE = os.environ.get('NINO26_RUN_PIPELINE', '0') == '1'
if RUN_PIPELINE:
    raise RuntimeError('O núcleo numérico deve ser executado pelo runner da fase, antes do notebook.')
from nino_brasil.notebook_workflows import NotebookWorkflow
workflow = NotebookWorkflow(ROOT, NOTEBOOK_CODE, mode=MODE)
workflow.describe()

# %% [markdown]
# **DADOS**

# %%
input_inventory = workflow.input_inventory()
display(input_inventory)
workflow.require_inputs()

# %% [markdown]
# **RESULTADOS**

# %%
result = workflow.run()
display(result.artifacts)
display(result.summary)

# %% [markdown]
# **FIGURAS PARA VERIFICAÇÃO RÁPIDA**

# %%
from IPython.display import Image, display

for artifact in result.artifacts.itertuples(index=False):
    display(Image(filename=str(artifact.figure_path)))

# %% [markdown]
# **CONCLUSÕES**

# %%
for item in result.takeaways:
    print(f'- {item}')
print('\nLimitações:')
for item in result.limitations:
    print(f'- {item}')

# %% [markdown]
# **REFERÊNCIAS BIBLIOGRÁFICAS**
#
# 1. NINO-BRASIL. Documentação metodológica, contrato de dados e diretrizes da fase no repositório do projeto.
