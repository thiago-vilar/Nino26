# %% [markdown]
# # F3NinaI — Interpretação integrada: La Niña
#
# **Projeto:** NINO-BRASIL — Oceanografia Física — UFPE
# **Código canônico:** `F3NinaI`
# **Objeto de estudo:** ciclo de vida da La Niña no Pacífico tropical
# **Família de hipótese:** `HIP0`
#
# ## 1. Contexto e delimitação científica
#
# Este notebook integra três dimensões que não podem ser confundidas: diferença entre fases, antecedência temporal e estabilidade entre eventos. Uma variável só ganha interpretação forte quando as evidências convergem e a direção permanece fisicamente plausível.
#
# ## 2. Pergunta científica
#
# Quais variáveis reúnem efeito entre fases, antecipação e estabilidade?
#
# ## 3. Hipótese específica
#
# Um subconjunto das 31 variáveis reúne, para La Niña, efeito entre fases, lag antecedente e estabilidade entre eventos; variáveis apoiadas por apenas uma dimensão permanecem evidência parcial.
#
# A hipótese poderá ser sustentada, parcialmente sustentada ou rejeitada; a execução do notebook não antecipa o resultado.
#
# ## 4. Motivação para o teste e unidade de análise
#
# A síntese cruza tabelas confirmatórias já produzidas, sem reabrir testes nem criar um novo limiar pós-hoc. Cada conclusão aponta para efeito, lag e estabilidade que a sustentam, preservando resultados nulos e divergências.
#
# ## 5. Metodologia
#
# Integração auditável dos rankings FDR, lags e estabilidade sem criar nova família confirmatória pós-hoc.
#
# ## 6. Resultados esperados e contrato de saída
#
# Resultados esperados significam produtos necessários para responder à pergunta, não valores ou significâncias presumidos:
#
# - matriz integrada variável × fase com efeito, lag e estabilidade.
# - classificação transparente entre evidência convergente, parcial e ausente.
# - tabela de rastreabilidade de cada interpretação às análises de origem.
#
# - figuras públicas iniciadas por `FigF3NinaI`;
# - tabelas públicas iniciadas por `TabF3NinaI`;
# - primeiro par reservado: `FigF3NinaI1` ↔ `TabF3NinaI1`;
# - toda interpretação deve apontar para tabela, run_id, unidade, amostra e limitações.
#
# ## 7. Fundamentação científica mínima
#
# 1. Timmermann, A. et al. (2018). El Niño–Southern Oscillation complexity. Nature, 559, 535–545.
# 2. Cawley, G. C.; Talbot, N. L. C. (2010). On Over-fitting in Model Selection and Subsequent Selection Bias. Journal of Machine Learning Research, 11, 2079–2107.

# %% [markdown]
# ## Premissas de validade e limites de interpretação
#
# - Toda conclusão deve nascer de uma tabela `Tab...` persistida antes da figura correspondente.
# - A execução é determinística e usa somente entradas declaradas no inventário mostrado abaixo.
# - Notebook executado não implica hipótese confirmada; gates científicos são exibidos como resultados.
# - El Niño e La Niña são analisados isoladamente; nenhum composto mistura os dois sinais.
# - Evento é a unidade independente; semanas descrevem a trajetória interna do evento.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
NOTEBOOK_CODE = 'F3NinaI'
MODE = os.environ.get('NINO26_NOTEBOOK_MODE', 'official')
RUN_PIPELINE = os.environ.get('NINO26_RUN_PIPELINE', '0') == '1'
if RUN_PIPELINE:
    raise RuntimeError('O núcleo numérico deve ser executado pelo runner da fase, antes do notebook.')
from nino_brasil.notebook_workflows import NotebookWorkflow
workflow = NotebookWorkflow(ROOT, NOTEBOOK_CODE, mode=MODE)
workflow.describe()
# Out:
# {
#   "notebook_code": "F3NinaI",
#   "phase": 3,
#   "enso_type": "la_nina",
#   "mode": "official",
#   "execution_policy": "numeric-core-first-viewer-publisher"
# }
# {'notebook_code': 'F3NinaI',
#  'phase': 3,
#  'enso_type': 'la_nina',
#  'mode': 'official',
#  'execution_policy': 'numeric-core-first-viewer-publisher'}

# %% [markdown]
# ## Dados

# %%
input_inventory = workflow.input_inventory()
display(input_inventory)
workflow.require_inputs()
# Out:
#                                  role  \
# 0                            lags FDR
# 1                 efeitos entre fases
# 2             estabilidade por evento
# 3  influência percentual por variável
# 4         variáveis-guia de transição
#
#                                                 path  required  exists   bytes
# 0  data\processed\parquet\statistics\F3Nina\TabF3...      True    True   16312
# 1  data\processed\parquet\statistics\F3Nina\TabF3...      True    True    9407
# 2  data\processed\parquet\statistics\F3Nina\TabF3...      True    True  149981
# 3  data\processed\parquet\statistics\F3Nina\TabF3...      True    True   47495
# 4  data\processed\parquet\statistics\F3Nina\TabF3...      True    True   44162

# %% [markdown]
# ## Resultados

# %%
result = workflow.run()
display(result.artifacts)
display(result.summary)
# Out:
#   notebook_code  ordinal   namespace                        figure_code  \
# 0       F3NinaI        1  fase3_nina      FigF3NinaI1_sintese_integrada
# 1       F3NinaI        2  fase3_nina  FigF3NinaI2_influencia_percentual
# 2       F3NinaI        3  fase3_nina   FigF3NinaI3_guias_transicao_fase
#
#                           table_code  \
# 0      TabF3NinaI1_sintese_integrada
# 1  TabF3NinaI2_influencia_percentual
# 2   TabF3NinaI3_guias_transicao_fase
#
#                                          figure_path  \
# 0  C:\DEV\NINO26\data\processed\figures\fase3_nin...
# 1  C:\DEV\NINO26\data\processed\figures\fase3_nin...
# 2  C:\DEV\NINO26\data\processed\figures\fase3_nin...
#
#                                           table_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
# 1  C:\DEV\NINO26\data\processed\numeric-tables\fa...
# 2  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        manifest_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
# 1  C:\DEV\NINO26\data\processed\numeric-tables\fa...
# 2  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        figure_sha256  \
# 0  216548b181da14847c207c70068e2a5d22e800a4675e2a...
# 1  9b6c6e4295a528aaa7d2f6c9cdbc02049abce42e318a24...
# 2  03824340f1c80ae7c5ad97779a2424fe8adcb3c1105ad0...
#
#                                         table_sha256  \
# 0  51b7f84070aba26405e692dd71c23b406e39706ce75e4a...
# 1  5d2844c6a5b789f998f781e33499a56bf1d34130ce9b42...
# 2  6700df4474ac977178b6ab77cd3d4c6882a7ffdec02772...
#
#                       run_id
# 0  20260714T202702Z_5538a635
# 1  20260714T202702Z_5538a635
# 2  20260714T202702Z_5538a635
#         tipo         fase       variavel               familia  \
# 0    la_nina  crescimento          d20_m  oceano_subsuperficie
# 1    la_nina  crescimento         tilt_m  oceano_subsuperficie
# 2    la_nina  crescimento     tilt_slope  oceano_subsuperficie
# 3    la_nina  crescimento      ohc_0_100  oceano_subsuperficie
# 4    la_nina  crescimento      ohc_0_300  oceano_subsuperficie
# ..       ...          ...            ...                   ...
# 145  la_nina        todas      u850_anom             atmosfera
# 146  la_nina        todas      u200_anom             atmosfera
# 147  la_nina        todas  omega850_anom             atmosfera
# 148  la_nina        todas  omega500_anom             atmosfera
# 149  la_nina        todas    div850_anom             atmosfera
#
#                                 metrica  valor_pct  \
# 0         peso_descritivo_do_estado_pct   6.063328
# 1         peso_descritivo_do_estado_pct   3.880931
# 2         peso_descritivo_do_estado_pct   2.646129
# 3         peso_descritivo_do_estado_pct   5.906735
# 4         peso_descritivo_do_estado_pct   6.071033
# ..                                  ...        ...
# 145  peso_discriminante_entre_fases_pct   4.846238
# 146  peso_discriminante_entre_fases_pct   4.077430
# 147  peso_discriminante_entre_fases_pct   2.539813
# 148  peso_discriminante_entre_fases_pct   2.814388
# 149  peso_discriminante_entre_fases_pct   2.924217
#
#                                           base_metrica  n_eventos  \
# 0    |media_z_entre_eventos| normalizada dentro da ...         11
# 1    |media_z_entre_eventos| normalizada dentro da ...         11
# 2    |media_z_entre_eventos| normalizada dentro da ...         11
# 3    |media_z_entre_eventos| normalizada dentro da ...         11
# 4    |media_z_entre_eventos| normalizada dentro da ...         11
# ..                                                 ...        ...
# 145  Kendall W do Friedman pareado normalizado entr...         11
# 146  Kendall W do Friedman pareado normalizado entr...         11
# 147  Kendall W do Friedman pareado normalizado entr...         11
# 148  Kendall W do Friedman pareado normalizado entr...         11
# 149  Kendall W do Friedman pareado normalizado entr...         11
#
#     confirmado_fdr                                      interpretacao
# 0              NaN  participacao relativa das variaveis fisicas co...
# 1              NaN  participacao relativa das variaveis fisicas co...
# 2              NaN  participacao relativa das variaveis fisicas co...
# 3              NaN  participacao relativa das variaveis fisicas co...
# 4              NaN  participacao relativa das variaveis fisicas co...
# ..             ...                                                ...
# 145           True  participacao relativa das variaveis fisicas co...
# 146           True  participacao relativa das variaveis fisicas co...
# 147           True  participacao relativa das variaveis fisicas co...
# 148           True  participacao relativa das variaveis fisicas co...
# 149           True  participacao relativa das variaveis fisicas co...
#
# [150 rows x 10 columns]

# %% [markdown]
# ## Figuras para verificação rápida

# %%
from IPython.display import Image, display

for artifact in result.artifacts.itertuples(index=False):
    display(Image(filename=str(artifact.figure_path)))

# %% [markdown]
# ## Conclusões

# %%
for item in result.takeaways:
    print(f'- {item}')
print('\nLimitações:')
for item in result.limitations:
    print(f'- {item}')
# Out:
# - A síntese integra 30 variáveis; o score soma |r| no melhor lag, Kendall W e estabilidade bootstrap.
# - A influência percentual é participação relativa (peso descritivo por fase e peso discriminante Kendall W), não variância explicada causal.
# - 9 marcadores físicos compõem os top-3 das transições adjacentes; eles são retrospectivos e não constituem detector online.
#
# Limitações:
# - As figuras resumem tabelas auditadas; consulte tabela, manifesto e unidade antes de interpretar valores individuais.
# - Leituras de propagação e influência são diagnósticas por evento; não há detector formal de onda nem atribuição causal.
# - Somente eventos elegíveis do sinal isolado entram nos painéis; o número de eventos independentes acompanha cada tabela.
