# %% [markdown]
# # F3NinaH — Gênese e precursores por classe: La Niña
#
# **Projeto:** NINO-BRASIL — Oceanografia Física — UFPE
# **Código canônico:** `F3NinaH`
# **Objeto de estudo:** ciclo de vida da La Niña no Pacífico tropical
# **Família de hipótese:** `HIP0`
#
# ## 1. Contexto e delimitação científica
#
# Este notebook concentra-se na gênese e pergunta se o estado precursor já contém informação sobre a intensidade futura do La Niña. A análise deve evitar vazamento: a caracterização da gênese usa apenas a janela definida para essa fase, ainda que a classe seja um rótulo retrospectivo do evento.
#
# ## 2. Pergunta científica
#
# Quais variáveis na gênese separam eventos fracos, moderados, fortes e muito fortes?
#
# ## 3. Hipótese específica
#
# Diferenças no pré-condicionamento oceânico e atmosférico durante a gênese separam parcialmente as classes futuras de La Niña, sobretudo em variáveis ligadas à recarga, termoclina e acoplamento do vento.
#
# A hipótese poderá ser sustentada, parcialmente sustentada ou rejeitada; a execução do notebook não antecipa o resultado.
#
# ## 4. Motivação para o teste e unidade de análise
#
# Calculam-se médias por evento na gênese e contrastes entre classes, com classificação pela magnitude absoluta do pico. O resultado é diagnóstico de separabilidade e não uma estimativa operacional de previsão.
#
# ## 5. Metodologia
#
# Médias por evento na gênese e contraste entre classes; classificação usa |ONI| para Niño e Niña separadamente.
#
# ## 6. Resultados esperados e contrato de saída
#
# Resultados esperados significam produtos necessários para responder à pergunta, não valores ou significâncias presumidos:
#
# - estado das 31 variáveis na gênese para cada evento.
# - contrastes e tamanhos de efeito entre classes de intensidade.
# - lista de candidatos precursores sem alegação automática de causalidade ou skill.
#
# - figuras públicas iniciadas por `FigF3NinaH`;
# - tabelas públicas iniciadas por `TabF3NinaH`;
# - primeiro par reservado: `FigF3NinaH1` ↔ `TabF3NinaH1`;
# - toda interpretação deve apontar para tabela, run_id, unidade, amostra e limitações.
#
# ## 7. Fundamentação científica mínima
#
# 1. Jin, F.-F. (1997). An Equatorial Ocean Recharge Paradigm for ENSO. Journal of the Atmospheric Sciences, 54, 811–829.
# 2. Meinen, C. S.; McPhaden, M. J. (2000). Observations of Warm Water Volume Changes in the Equatorial Pacific. Journal of Climate, 13, 3551–3559.

# %% [markdown]
# ## Premissas de validade e limites de interpretação
#
# - Toda conclusão deve nascer de uma tabela `Tab...` persistida antes da figura correspondente.
# - A execução é determinística e usa somente entradas declaradas no inventário mostrado abaixo.
# - Notebook executado não implica hipótese confirmada; gates científicos são exibidos como resultados.
# - El Niño e La Niña são analisados isoladamente; nenhum composto mistura os dois sinais.
# - Evento é a unidade independente; semanas descrevem a trajetória interna do evento.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
NOTEBOOK_CODE = 'F3NinaH'
MODE = os.environ.get('NINO26_NOTEBOOK_MODE', 'official')
RUN_PIPELINE = os.environ.get('NINO26_RUN_PIPELINE', '0') == '1'
if RUN_PIPELINE:
    raise RuntimeError('O núcleo numérico deve ser executado pelo runner da fase, antes do notebook.')
from nino_brasil.notebook_workflows import NotebookWorkflow
workflow = NotebookWorkflow(ROOT, NOTEBOOK_CODE, mode=MODE)
workflow.describe()
# Out:
# {
#   "notebook_code": "F3NinaH",
#   "phase": 3,
#   "enso_type": "la_nina",
#   "mode": "official",
#   "execution_policy": "numeric-core-first-viewer-publisher"
# }
# {'notebook_code': 'F3NinaH',
#  'phase': 3,
#  'enso_type': 'la_nina',
#  'mode': 'official',
#  'execution_policy': 'numeric-core-first-viewer-publisher'}

# %% [markdown]
# ## Dados

# %%
input_inventory = workflow.input_inventory()
display(input_inventory)
workflow.require_inputs()
# Out:
#                   role                                               path  \
# 0  gênese por variável  data\processed\parquet\statistics\F3Nina\TabF3...
#
#    required  exists  bytes
# 0      True    True  22377

# %% [markdown]
# ## Resultados

# %%
result = workflow.run()
display(result.artifacts)
display(result.summary)
# Out:
#   notebook_code  ordinal   namespace  figure_code   table_code  \
# 0       F3NinaH        1  fase3_nina  FigF3NinaH1  TabF3NinaH1
#
#                                          figure_path  \
# 0  C:\DEV\NINO26\data\processed\figures\fase3_nin...
#
#                                           table_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        manifest_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        figure_sha256  \
# 0  963afbf847937f87bacc55d772f10ccb31248c7964d3d1...
#
#                                         table_sha256  \
# 0  45a1bb9e3619687107f95c9b2cbb2c4124f2eb8f3186f6...
#
#                       run_id
# 0  20260714T202702Z_5538a635
#        tipo    fase       variavel  media_z_entre_eventos  \
# 78  la_nina  genese          t700m               0.028022
# 72  la_nina  genese           t50m               0.032844
# 77  la_nina  genese          t500m              -0.049464
# 66  la_nina  genese      ohc_0_100              -0.060072
# 69  la_nina  genese    ohc_300_700               0.074370
# 79  la_nina  genese     tau_x_anom               0.125167
# 84  la_nina  genese      slhf_anom               0.133972
# 85  la_nina  genese      sshf_anom               0.176785
# 70  la_nina  genese          ssh_m              -0.223819
# 80  la_nina  genese       u10_anom               0.224133
# 92  la_nina  genese    div850_anom              -0.233933
# 68  la_nina  genese      ohc_0_700              -0.284458
# 62  la_nina  genese    nino34_ssta               0.287180
# 88  la_nina  genese      u850_anom               0.290371
# 64  la_nina  genese         tilt_m               0.296805
# 67  la_nina  genese      ohc_0_300              -0.327733
# 91  la_nina  genese  omega500_anom              -0.333434
# 75  la_nina  genese          t200m              -0.365554
# 90  la_nina  genese  omega850_anom              -0.377920
# 89  la_nina  genese      u200_anom              -0.385546
# 83  la_nina  genese      tcwv_anom               0.398356
# 76  la_nina  genese          t300m               0.435042
# 86  la_nina  genese       ssr_anom              -0.450421
# 73  la_nina  genese          t100m              -0.452524
# 87  la_nina  genese       str_anom               0.482039
# 65  la_nina  genese     tilt_slope               0.487963
# 81  la_nina  genese       v10_anom              -0.511952
# 74  la_nina  genese          t150m              -0.664155
# 63  la_nina  genese          d20_m              -0.692829
# 71  la_nina  genese            wwv              -0.748413
#
#     desvio_z_entre_eventos  volatilidade_semanal_media_entre_eventos  \
# 78                1.235961                                  0.192064
# 72                0.637744                                  0.123521
# 77                0.779115                                  0.251421
# 66                0.615226                                  0.121492
# 69                0.801778                                  0.261749
# 79                0.678292                                  0.703013
# 84                0.641027                                  0.672449
# 85                0.755936                                  0.478694
# 70                0.454539                                  0.155417
# 80                0.864634                                  0.671243
# 92                0.876185                                  0.697397
# 68                0.535859                                  0.157379
# 62                0.714118                                  0.181746
# 88                0.775707                                  0.592339
# 64                0.891761                                  0.110346
# 67                0.510916                                  0.138936
# 91                1.268728                                  0.574159
# 75                0.372638                                  0.199485
# 90                1.031737                                  0.478994
# 89                0.830818                                  0.646939
# 83                0.947679                                  0.396566
# 76                0.831770                                  0.194580
# 86                1.267411                                  0.481209
# 73                0.615823                                  0.148182
# 87                0.933916                                  0.568233
# 65                1.179985                                  0.176948
# 81                1.244469                                  0.575817
# 74                0.471172                                  0.164379
# 63                0.646539                                  0.146203
# 71                0.744394                                  0.093840
#
#     n_eventos_independentes  n_semanas_descritivas  nivel_z_medio  \
# 78                       11                    256       0.028022
# 72                       11                    256       0.032844
# 77                       11                    256      -0.049464
# 66                       11                    256      -0.060072
# 69                       11                    256       0.074370
# 79                       11                    256       0.125167
# 84                       11                    256       0.133972
# 85                       11                    256       0.176785
# 70                       11                    256      -0.223819
# 80                       11                    256       0.224133
# 92                       11                    256      -0.233933
# 68                       11                    256      -0.284458
# 62                       11                    256       0.287180
# 88                       11                    256       0.290371
# 64                       11                    256       0.296805
# 67                       11                    256      -0.327733
# 91                       11                    256      -0.333434
# 75                       11                    256      -0.365554
# 90                       11                    256      -0.377920
# 89                       11                    256      -0.385546
# 83                       11                    256       0.398356
# 76                       11                    256       0.435042
# 86                       11                    256      -0.450421
# 73                       11                    256      -0.452524
# 87                       11                    256       0.482039
# 65                       11                    256       0.487963
# 81                       11                    256      -0.511952
# 74                       11                    256      -0.664155
# 63                       11                    256      -0.692829
# 71                       11                    256      -0.748413
#
#     volatilidade_sem  n_semanas unidade_inferencial            evaluation_mode
# 78          0.192064        256   media_evento_fase  diagnostico_retrospectivo
# 72          0.123521        256   media_evento_fase  diagnostico_retrospectivo
# 77          0.251421        256   media_evento_fase  diagnostico_retrospectivo
# 66          0.121492        256   media_evento_fase  diagnostico_retrospectivo
# 69          0.261749        256   media_evento_fase  diagnostico_retrospectivo
# 79          0.703013        256   media_evento_fase  diagnostico_retrospectivo
# 84          0.672449        256   media_evento_fase  diagnostico_retrospectivo
# 85          0.478694        256   media_evento_fase  diagnostico_retrospectivo
# 70          0.155417        256   media_evento_fase  diagnostico_retrospectivo
# 80          0.671243        256   media_evento_fase  diagnostico_retrospectivo
# 92          0.697397        256   media_evento_fase  diagnostico_retrospectivo
# 68          0.157379        256   media_evento_fase  diagnostico_retrospectivo
# 62          0.181746        256   media_evento_fase  diagnostico_retrospectivo
# 88          0.592339        256   media_evento_fase  diagnostico_retrospectivo
# 64          0.110346        256   media_evento_fase  diagnostico_retrospectivo
# 67          0.138936        256   media_evento_fase  diagnostico_retrospectivo
# 91          0.574159        256   media_evento_fase  diagnostico_retrospectivo
# 75          0.199485        256   media_evento_fase  diagnostico_retrospectivo
# 90          0.478994        256   media_evento_fase  diagnostico_retrospectivo
# 89          0.646939        256   media_evento_fase  diagnostico_retrospectivo
# 83          0.396566        256   media_evento_fase  diagnostico_retrospectivo
# 76          0.194580        256   media_evento_fase  diagnostico_retrospectivo
# 86          0.481209        256   media_evento_fase  diagnostico_retrospectivo
# 73          0.148182        256   media_evento_fase  diagnostico_retrospectivo
# 87          0.568233        256   media_evento_fase  diagnostico_retrospectivo
# 65          0.176948        256   media_evento_fase  diagnostico_retrospectivo
# 81          0.575817        256   media_evento_fase  diagnostico_retrospectivo
# 74          0.164379        256   media_evento_fase  diagnostico_retrospectivo
# 63          0.146203        256   media_evento_fase  diagnostico_retrospectivo
# 71          0.093840        256   media_evento_fase  diagnostico_retrospectivo

# %% [markdown]
# ## Figuras para verificação rápida

# %%
from IPython.display import Image, display

for artifact in result.artifacts.itertuples(index=False):
    display(Image(filename=str(artifact.figure_path)))

# %% [markdown]
# ## Conclusões

# %%
for item in result.takeaways:
    print(f'- {item}')
print('\nLimitações:')
for item in result.limitations:
    print(f'- {item}')
# Out:
# - A tabela auditada contém 30 linhas para La Niña.
# - A leitura mantém eventos independentes separados e não soma semanas como novas réplicas.
#
# Limitações:
# - A figura resume a tabela publicada; consulte a tabela completa e seu manifesto antes de interpretar valores individuais.
# - Resultados negativos ou tabelas vazias são preservados e não são convertidos em falha técnica.
