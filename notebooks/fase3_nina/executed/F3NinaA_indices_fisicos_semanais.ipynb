# %% [markdown]
# # F3NinaA — Índices físicos semanais: La Niña
#
# **Projeto:** NINO-BRASIL — Oceanografia Física — UFPE
# **Código canônico:** `F3NinaA`
# **Objeto de estudo:** ciclo de vida da La Niña no Pacífico tropical
# **Família de hipótese:** `HIP0`
#
# ## 1. Contexto e delimitação científica
#
# Este notebook apresenta a série histórica semanal completa das 31 variáveis do Pacífico tropical que sustentam a análise de El Niño. Os índices são separados em painéis oceânicos e atmosféricos; para cada variável, o leitor vê o valor semanal original do master, unidade, fonte e tendência linear de longo prazo. O objetivo é sanidade e contexto físico da série, não testar ainda diferenças entre fases.
#
# ## 2. Pergunta científica
#
# Como evoluem historicamente os 31 índices semanais oceânicos e atmosféricos do El Niño?
#
# ## 3. Hipótese específica
#
# Os índices oceânicos e atmosféricos exibem trajetórias históricas observáveis e tendências descritivas próprias; essas tendências não devem ser confundidas com efeito de fase, causalidade ou poder preditivo do El Niño.
#
# A hipótese poderá ser sustentada, parcialmente sustentada ou rejeitada; a execução do notebook não antecipa o resultado.
#
# ## 4. Motivação para o teste e unidade de análise
#
# Cada série é mantida na unidade do master semanal e recebe uma tendência OLS calculada sobre todo o período disponível, apenas como referência visual. A separação oceano/atmosfera evita escalas incompatíveis no mesmo eixo. Como semanas são autocorrelacionadas, a tendência não recebe p-valor nem é usada como teste; evento-fase, lags e robustez são avaliados nos blocos F3NinoC–E.
#
# ## 5. Metodologia
#
# Séries semanais completas, separadas por família física, com tendência OLS descritiva por variável; comparações inferenciais entre fases permanecem nos notebooks próprios.
#
# ## 6. Resultados esperados e contrato de saída
#
# Resultados esperados significam produtos necessários para responder à pergunta, não valores ou significâncias presumidos:
#
# - painel completo dos índices oceânicos semanais, com série original e tendência OLS por variável.
# - painel completo dos índices atmosféricos semanais, com série original e tendência OLS por variável.
# - tabelas longas auditáveis com cada semana, unidade, fonte, representação e tendência correspondente.
#
# - figuras públicas iniciadas por `FigF3NinaA`;
# - tabelas públicas iniciadas por `TabF3NinaA`;
# - primeiro par reservado: `FigF3NinaA1` ↔ `TabF3NinaA1`;
# - toda interpretação deve apontar para tabela, run_id, unidade, amostra e limitações.
#
# ## 7. Fundamentação científica mínima
#
# 1. Bjerknes, J. (1969). Atmospheric Teleconnections from the Equatorial Pacific. Monthly Weather Review, 97, 163–172.
# 2. Trenberth, K. E. (1997). The Definition of El Niño. Bulletin of the American Meteorological Society, 78, 2771–2777.

# %% [markdown]
# ## Premissas de validade e limites de interpretação
#
# - Toda conclusão deve nascer de uma tabela `Tab...` persistida antes da figura correspondente.
# - A execução é determinística e usa somente entradas declaradas no inventário mostrado abaixo.
# - Notebook executado não implica hipótese confirmada; gates científicos são exibidos como resultados.
# - El Niño e La Niña são analisados isoladamente; nenhum composto mistura os dois sinais.
# - Evento é a unidade independente; semanas descrevem a trajetória interna do evento.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
NOTEBOOK_CODE = 'F3NinaA'
MODE = os.environ.get('NINO26_NOTEBOOK_MODE', 'official')
RUN_PIPELINE = os.environ.get('NINO26_RUN_PIPELINE', '0') == '1'
if RUN_PIPELINE:
    raise RuntimeError('O núcleo numérico deve ser executado pelo runner da fase, antes do notebook.')
from nino_brasil.notebook_workflows import NotebookWorkflow
workflow = NotebookWorkflow(ROOT, NOTEBOOK_CODE, mode=MODE)
workflow.describe()
# Out:
# {
#   "notebook_code": "F3NinaA",
#   "phase": 3,
#   "enso_type": "la_nina",
#   "mode": "official",
#   "execution_policy": "numeric-core-first-viewer-publisher"
# }
# {'notebook_code': 'F3NinaA',
#  'phase': 3,
#  'enso_type': 'la_nina',
#  'mode': 'official',
#  'execution_policy': 'numeric-core-first-viewer-publisher'}

# %% [markdown]
# ## Dados

# %%
input_inventory = workflow.input_inventory()
display(input_inventory)
workflow.require_inputs()
# Out:
#                         role  \
# 0   estatísticas evento-fase
# 1        índices semanais F2
# 2  contrato das 31 variáveis
#
#                                                 path  required  exists  \
# 0  data\processed\parquet\statistics\F3Nina\TabF3...      True    True
# 1  data\processed\parquet\features\nino34_master_...      True    True
# 2  data\processed\parquet\statistics\phase2_varia...      True    True
#
#      bytes
# 0    22377
# 1  1424012
# 2     2919

# %% [markdown]
# ## Resultados

# %%
result = workflow.run()
display(result.artifacts)
display(result.summary)
# Out:
#   notebook_code  ordinal   namespace  figure_code   table_code  \
# 0       F3NinaA        1  fase3_nina  FigF3NinaA1  TabF3NinaA1
#
#                                          figure_path  \
# 0  C:\DEV\NINO26\data\processed\figures\fase3_nin...
#
#                                           table_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        manifest_path  \
# 0  C:\DEV\NINO26\data\processed\numeric-tables\fa...
#
#                                        figure_sha256  \
# 0  b61f49cc9036f1be6084e18eedee7cd00f57cb13c8b0f9...
#
#                                         table_sha256  \
# 0  e229164d1f6c4709246348dadde0fad532ba727a96e760...
#
#                       run_id
# 0  20260714T202702Z_5538a635
#         tipo         fase       variavel  media_z_entre_eventos  \
# 0    la_nina  crescimento    nino34_ssta              -0.928987
# 2    la_nina  crescimento         tilt_m              -0.752835
# 3    la_nina  crescimento     tilt_slope              -0.513304
# 4    la_nina  crescimento      ohc_0_100              -1.145807
# 9    la_nina  crescimento            wwv              -1.002742
# 10   la_nina  crescimento           t50m              -1.112238
# 14   la_nina  crescimento          t300m              -0.420445
# 21   la_nina  crescimento      tcwv_anom              -0.438817
# 23   la_nina  crescimento      sshf_anom              -0.596831
# 26   la_nina  crescimento      u850_anom              -0.623555
# 27   la_nina  crescimento      u200_anom               0.520535
# 28   la_nina  crescimento  omega850_anom               0.450838
# 31   la_nina   decaimento    nino34_ssta              -0.859523
# 33   la_nina   decaimento         tilt_m              -0.904715
# 34   la_nina   decaimento     tilt_slope              -0.853873
# 35   la_nina   decaimento      ohc_0_100              -0.777360
# 40   la_nina   decaimento            wwv               0.170484
# 41   la_nina   decaimento           t50m              -0.821654
# 45   la_nina   decaimento          t300m              -0.665722
# 52   la_nina   decaimento      tcwv_anom              -0.598099
# 54   la_nina   decaimento      sshf_anom              -0.547916
# 57   la_nina   decaimento      u850_anom              -0.371911
# 58   la_nina   decaimento      u200_anom               0.708827
# 59   la_nina   decaimento  omega850_anom               0.353072
# 62   la_nina       genese    nino34_ssta               0.287180
# 64   la_nina       genese         tilt_m               0.296805
# 65   la_nina       genese     tilt_slope               0.487963
# 66   la_nina       genese      ohc_0_100              -0.060072
# 71   la_nina       genese            wwv              -0.748413
# 72   la_nina       genese           t50m               0.032844
# 76   la_nina       genese          t300m               0.435042
# 83   la_nina       genese      tcwv_anom               0.398356
# 85   la_nina       genese      sshf_anom               0.176785
# 88   la_nina       genese      u850_anom               0.290371
# 89   la_nina       genese      u200_anom              -0.385546
# 90   la_nina       genese  omega850_anom              -0.377920
# 93   la_nina         pico    nino34_ssta              -1.449389
# 95   la_nina         pico         tilt_m              -1.216624
# 96   la_nina         pico     tilt_slope              -0.760415
# 97   la_nina         pico      ohc_0_100              -1.359994
# 102  la_nina         pico            wwv              -0.654263
# 103  la_nina         pico           t50m              -1.376847
# 107  la_nina         pico          t300m              -0.637229
# 114  la_nina         pico      tcwv_anom              -0.951841
# 116  la_nina         pico      sshf_anom              -0.819834
# 119  la_nina         pico      u850_anom              -0.853517
# 120  la_nina         pico      u200_anom               0.777804
# 121  la_nina         pico  omega850_anom               0.820165
#
#      desvio_z_entre_eventos  volatilidade_semanal_media_entre_eventos  \
# 0                  0.286429                                  0.179169
# 2                  0.269406                                  0.088591
# 3                  0.288322                                  0.143947
# 4                  0.389686                                  0.093244
# 9                  0.819116                                  0.082914
# 10                 0.412883                                  0.095972
# 14                 0.700056                                  0.164260
# 21                 0.435186                                  0.272098
# 23                 0.357883                                  0.306358
# 26                 0.271635                                  0.601835
# 27                 0.234555                                  0.737133
# 28                 0.360997                                  0.230985
# 31                 0.142269                                  0.175327
# 33                 0.360862                                  0.105001
# 34                 0.301661                                  0.157390
# 35                 0.256520                                  0.080022
# 40                 0.916943                                  0.085866
# 41                 0.231393                                  0.075400
# 45                 0.862978                                  0.177163
# 52                 0.277148                                  0.386327
# 54                 0.292037                                  0.374792
# 57                 0.234791                                  0.629571
# 58                 0.414976                                  0.639801
# 59                 0.524359                                  0.425367
# 62                 0.714118                                  0.181746
# 64                 0.891761                                  0.110346
# 65                 1.179985                                  0.176948
# 66                 0.615226                                  0.121492
# 71                 0.744394                                  0.093840
# 72                 0.637744                                  0.123521
# 76                 0.831770                                  0.194580
# 83                 0.947679                                  0.396566
# 85                 0.755936                                  0.478694
# 88                 0.775707                                  0.592339
# 89                 0.830818                                  0.646939
# 90                 1.031737                                  0.478994
# 93                 0.426158                                  0.199546
# 95                 0.536080                                  0.083378
# 96                 0.291530                                  0.117878
# 97                 0.570526                                  0.060641
# 102                0.933665                                  0.097749
# 103                0.561882                                  0.064326
# 107                0.784951                                  0.177513
# 114                0.387367                                  0.322916
# 116                0.353495                                  0.319905
# 119                0.399495                                  0.483773
# 120                0.597334                                  0.661909
# 121                0.340922                                  0.271380
#
#      n_eventos_independentes  n_semanas_descritivas  nivel_z_medio  \
# 0                         11                    235      -0.928987
# 2                         11                    235      -0.752835
# 3                         11                    235      -0.513304
# 4                         11                    235      -1.145807
# 9                         11                    235      -1.002742
# 10                        11                    235      -1.112238
# 14                        11                    235      -0.420445
# 21                        11                    235      -0.438817
# 23                        11                    235      -0.596831
# 26                        11                    235      -0.623555
# 27                        11                    235       0.520535
# 28                        11                    235       0.450838
# 31                        11                    294      -0.859523
# 33                        11                    294      -0.904715
# 34                        11                    294      -0.853873
# 35                        11                    294      -0.777360
# 40                        11                    294       0.170484
# 41                        11                    294      -0.821654
# 45                        11                    294      -0.665722
# 52                        11                    294      -0.598099
# 54                        11                    294      -0.547916
# 57                        11                    294      -0.371911
# 58                        11                    294       0.708827
# 59                        11                    294       0.353072
# 62                        11                    256       0.287180
# 64                        11                    256       0.296805
# 65                        11                    256       0.487963
# 66                        11                    256      -0.060072
# 71                        11                    256      -0.748413
# 72                        11                    256       0.032844
# 76                        11                    256       0.435042
# 83                        11                    256       0.398356
# 85                        11                    256       0.176785
# 88                        11                    256       0.290371
# 89                        11                    256      -0.385546
# 90                        11                    256      -0.377920
# 93                        11                    122      -1.449389
# 95                        11                    122      -1.216624
# 96                        11                    122      -0.760415
# 97                        11                    122      -1.359994
# 102                       11                    122      -0.654263
# 103                       11                    122      -1.376847
# 107                       11                    122      -0.637229
# 114                       11                    122      -0.951841
# 116                       11                    122      -0.819834
# 119                       11                    122      -0.853517
# 120                       11                    122       0.777804
# 121                       11                    122       0.820165
#
#      volatilidade_sem  n_semanas unidade_inferencial  \
# 0            0.179169        235   media_evento_fase
# 2            0.088591        235   media_evento_fase
# 3            0.143947        235   media_evento_fase
# 4            0.093244        235   media_evento_fase
# 9            0.082914        235   media_evento_fase
# 10           0.095972        235   media_evento_fase
# 14           0.164260        235   media_evento_fase
# 21           0.272098        235   media_evento_fase
# 23           0.306358        235   media_evento_fase
# 26           0.601835        235   media_evento_fase
# 27           0.737133        235   media_evento_fase
# 28           0.230985        235   media_evento_fase
# 31           0.175327        294   media_evento_fase
# 33           0.105001        294   media_evento_fase
# 34           0.157390        294   media_evento_fase
# 35           0.080022        294   media_evento_fase
# 40           0.085866        294   media_evento_fase
# 41           0.075400        294   media_evento_fase
# 45           0.177163        294   media_evento_fase
# 52           0.386327        294   media_evento_fase
# 54           0.374792        294   media_evento_fase
# 57           0.629571        294   media_evento_fase
# 58           0.639801        294   media_evento_fase
# 59           0.425367        294   media_evento_fase
# 62           0.181746        256   media_evento_fase
# 64           0.110346        256   media_evento_fase
# 65           0.176948        256   media_evento_fase
# 66           0.121492        256   media_evento_fase
# 71           0.093840        256   media_evento_fase
# 72           0.123521        256   media_evento_fase
# 76           0.194580        256   media_evento_fase
# 83           0.396566        256   media_evento_fase
# 85           0.478694        256   media_evento_fase
# 88           0.592339        256   media_evento_fase
# 89           0.646939        256   media_evento_fase
# 90           0.478994        256   media_evento_fase
# 93           0.199546        122   media_evento_fase
# 95           0.083378        122   media_evento_fase
# 96           0.117878        122   media_evento_fase
# 97           0.060641        122   media_evento_fase
# 102          0.097749        122   media_evento_fase
# 103          0.064326        122   media_evento_fase
# 107          0.177513        122   media_evento_fase
# 114          0.322916        122   media_evento_fase
# 116          0.319905        122   media_evento_fase
# 119          0.483773        122   media_evento_fase
# 120          0.661909        122   media_evento_fase
# 121          0.271380        122   media_evento_fase
#
#                evaluation_mode
# 0    diagnostico_retrospectivo
# 2    diagnostico_retrospectivo
# 3    diagnostico_retrospectivo
# 4    diagnostico_retrospectivo
# 9    diagnostico_retrospectivo
# 10   diagnostico_retrospectivo
# 14   diagnostico_retrospectivo
# 21   diagnostico_retrospectivo
# 23   diagnostico_retrospectivo
# 26   diagnostico_retrospectivo
# 27   diagnostico_retrospectivo
# 28   diagnostico_retrospectivo
# 31   diagnostico_retrospectivo
# 33   diagnostico_retrospectivo
# 34   diagnostico_retrospectivo
# 35   diagnostico_retrospectivo
# 40   diagnostico_retrospectivo
# 41   diagnostico_retrospectivo
# 45   diagnostico_retrospectivo
# 52   diagnostico_retrospectivo
# 54   diagnostico_retrospectivo
# 57   diagnostico_retrospectivo
# 58   diagnostico_retrospectivo
# 59   diagnostico_retrospectivo
# 62   diagnostico_retrospectivo
# 64   diagnostico_retrospectivo
# 65   diagnostico_retrospectivo
# 66   diagnostico_retrospectivo
# 71   diagnostico_retrospectivo
# 72   diagnostico_retrospectivo
# 76   diagnostico_retrospectivo
# 83   diagnostico_retrospectivo
# 85   diagnostico_retrospectivo
# 88   diagnostico_retrospectivo
# 89   diagnostico_retrospectivo
# 90   diagnostico_retrospectivo
# 93   diagnostico_retrospectivo
# 95   diagnostico_retrospectivo
# 96   diagnostico_retrospectivo
# 97   diagnostico_retrospectivo
# 102  diagnostico_retrospectivo
# 103  diagnostico_retrospectivo
# 107  diagnostico_retrospectivo
# 114  diagnostico_retrospectivo
# 116  diagnostico_retrospectivo
# 119  diagnostico_retrospectivo
# 120  diagnostico_retrospectivo
# 121  diagnostico_retrospectivo

# %% [markdown]
# ## Figuras para verificação rápida

# %%
from IPython.display import Image, display

for artifact in result.artifacts.itertuples(index=False):
    display(Image(filename=str(artifact.figure_path)))

# %% [markdown]
# ## Conclusões

# %%
for item in result.takeaways:
    print(f'- {item}')
print('\nLimitações:')
for item in result.limitations:
    print(f'- {item}')
# Out:
# - A tabela auditada contém 48 linhas para La Niña.
# - A leitura mantém eventos independentes separados e não soma semanas como novas réplicas.
#
# Limitações:
# - A figura resume a tabela publicada; consulte a tabela completa e seu manifesto antes de interpretar valores individuais.
# - Resultados negativos ou tabelas vazias são preservados e não são convertidos em falha técnica.
