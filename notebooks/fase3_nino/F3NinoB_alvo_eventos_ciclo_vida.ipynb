# %% [markdown]
# **TÍTULO**
#
# F3NinoB — Ciclo de vida dos El Niños fortes (pico ≥ 1 °C): El Niño
#
# **Projeto:** NINO-BRASIL — Oceanografia Física — UFPE
# **Código canônico:** `F3NinoB`
# **Objeto de estudo:** ciclo de vida do El Niño no Pacífico tropical
# **Família de hipótese:** `HIP0`
#
# **CONTEXTO**
#
# Este notebook constrói o catálogo local de eventos e a segmentação do ciclo de vida usados por todas as análises posteriores. A diretriz do escopo El Niño toma como base os eventos considerados fortes — anomalia de pico acima de 1 °C (classes moderado, forte e muito forte) — porque são eles que carregam sinal físico suficiente para a caracterização robusta das quatro fases. Gênese, crescimento, faixa de pico e decaimento recebem definições reproduzíveis e específicas do sinal quente.
#
# **PERGUNTA CIENTÍFICA**
#
# Quando começam e terminam gênese, crescimento, faixa de pico e decaimento nos El Niños com anomalia de pico acima de 1 °C?
#
# **MOTIVAÇÃO**
#
# *Hipótese específica*
#
# Os El Niños com pico acima de 1 °C formam trajetórias coerentes em quatro fases, e o pico é melhor representado por uma faixa relativa ao extremo de cada evento do que por uma única semana.
#
# A hipótese poderá ser sustentada, parcialmente sustentada ou rejeitada; a execução do notebook não antecipa o resultado.
#
# *Função dos testes e unidade de análise*
#
# A regra |ONI| ≥ 0,5 °C por cinco estações delimita os eventos; a elegibilidade pico ≥ 1,0 °C seleciona a base de análise sem apagar os eventos fracos do catálogo, que permanecem com flag para auditoria. A gênese é a janela pré-onset (bibliografia de recarga), e a faixa de pico é derivada do extremo interno com sensibilidade 80/90/95%.
#
# **METODOLOGIA**
#
# Eventos ONI locais (|ONI| ≥ 0,5 °C por cinco estações) com elegibilidade adicional de pico ≥ 1,0 °C; faixa de pico relativa ao extremo de cada evento; catálogo completo preservado com a flag de elegibilidade.
#
# **RESULTADOS ESPERADOS**
#
# Resultados esperados significam produtos necessários para responder à pergunta, não valores ou significâncias presumidos:
#
# - catálogo completo de eventos com intensidade, classe e flag de elegibilidade (pico ≥ 1 °C).
# - rótulo semanal de gênese, crescimento, faixa de pico e decaimento dos eventos elegíveis.
# - linha do tempo de cada evento e sensibilidade conjunta das quatro fases para gênese 13/26/39 semanas e pico 80/90/95%.
#
# - figuras públicas iniciadas por `FigF3NinoB`;
# - tabelas públicas iniciadas por `TabF3NinoB`;
# - primeiro par reservado: `FigF3NinoB1` ↔ `TabF3NinoB1`;
# - toda interpretação deve apontar para tabela, run_id, unidade, amostra e limitações.
#
# *Fundamentação científica mínima*
#
# As referências completas utilizadas estão na última célula do notebook.

# %% [markdown]
# **PREMISSAS DE VALIDADE E LIMITES DE INTERPRETAÇÃO**
#
# - Toda conclusão deve nascer de uma tabela `Tab...` persistida antes da figura correspondente.
# - A execução é determinística e usa somente entradas declaradas no inventário mostrado abaixo.
# - Notebook executado não implica hipótese confirmada; gates científicos são exibidos como resultados.
# - El Niño e La Niña são analisados isoladamente; nenhum composto mistura os dois sinais.
# - Evento é a unidade independente; semanas descrevem a trajetória interna do evento.

# %%
from pathlib import Path
import os
import sys
from IPython.display import display

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'pyproject.toml').exists())
SRC = ROOT / 'src'
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))
NOTEBOOK_CODE = 'F3NinoB'
MODE = os.environ.get('NINO26_NOTEBOOK_MODE', 'official')
RUN_PIPELINE = os.environ.get('NINO26_RUN_PIPELINE', '0') == '1'
if RUN_PIPELINE:
    raise RuntimeError('O núcleo numérico deve ser executado pelo runner da fase, antes do notebook.')
from nino_brasil.notebook_workflows import NotebookWorkflow
workflow = NotebookWorkflow(ROOT, NOTEBOOK_CODE, mode=MODE)
workflow.describe()

# %% [markdown]
# **DADOS**

# %%
input_inventory = workflow.input_inventory()
display(input_inventory)
workflow.require_inputs()

# %% [markdown]
# **RESULTADOS**

# %%
result = workflow.run()
display(result.artifacts)
display(result.summary)

# %% [markdown]
# **FIGURAS PARA VERIFICAÇÃO RÁPIDA**

# %%
from IPython.display import Image, display

for artifact in result.artifacts.itertuples(index=False):
    display(Image(filename=str(artifact.figure_path)))

# %% [markdown]
# **CONCLUSÕES**

# %%
for item in result.takeaways:
    print(f'- {item}')
print('\nLimitações:')
for item in result.limitations:
    print(f'- {item}')

# %% [markdown]
# **REFERÊNCIAS BIBLIOGRÁFICAS**
#
# 1. NOAA/CPC. Oceanic Niño Index (ONI v5): Niño 3.4, limiar ±0,5 °C por cinco estações móveis sobrepostas.
# 2. Trenberth, K. E. (1997). The Definition of El Niño. Bulletin of the American Meteorological Society, 78, 2771–2777.
# 3. Timmermann, A. et al. (2018). El Niño–Southern Oscillation complexity. Nature, 559, 535–545.
# 4. Jin, F.-F. (1997). An Equatorial Ocean Recharge Paradigm for ENSO. Journal of the Atmospheric Sciences, 54, 811–829.
