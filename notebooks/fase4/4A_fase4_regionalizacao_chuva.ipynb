# %% [markdown]
# # Fase 4A - Regionalizacao da chuva
#
# Pergunta: onde o Brasil responde de forma homogenea?
#
# Contrato: usar CHIRPS no eixo semanal canonico de 7 dias, derivar EOF/REOF e clusters de pixels, e salvar regioes-alvo para 4B, 4D, 5B e 6C.
#
# Saidas esperadas:
#
# - `data/processed/parquet/statistics/phase4a_clusters_brasil.csv`
# - `data/processed/zarr/statistics/phase4a_data_driven_regions.zarr`
