# %% [markdown]
# # Fase 4C - Modos acoplados
#
# Pergunta: quais padroes conjuntos SST(Pacifico+Atlantico) x chuva dominam?
#
# Contrato: rodar EOF, MCA/SVD e CCA com ajuste dentro do treino quando houver inferencia/skill; tratar colinearidade com VIF, parcial, LASSO/elastic-net e stability selection.
#
# Saidas esperadas:
#
# - `data/processed/zarr/statistics/phase4c_rainfall_eof_modes.zarr`
# - `data/processed/zarr/statistics/phase4c_pacific_atlantic_eof_modes.zarr`
# - `data/processed/zarr/statistics/phase4c_mca_coupled_modes.zarr`
# - `data/processed/parquet/statistics/phase4c_independent_variable_selection.csv`
